# %% [markdown]
# Scrapy modul creates automatically the required file and folders for you. However you do not always need them. Simply you can write your code in Jupiter Notebook and run it.

# %% [markdown]
# Here is an example:
#
# The code below scraps the information of cars in autoscout24.com webpage.
# Here is you can see the selected model's information:
#
# make-model : BMW X3
# year : 2018
# gear type : Automatic
#
# And an important note: Please check the websites robots.txt page that you would like to scrape. you can see if there are any restrictions about scraping that url.
#
# For Autoscout24.com you can see the robots.txt file simply writing this:
# "https://www.autoscout24.com/robots.txt"

# %%
conda install -c conda-forge scrapy
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\msmsk\anaconda3
#
#   added / updated specs:
#     - scrapy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     automat-20.2.0             |             py_0          30 KB  conda-forge
#     conda-4.8.5                |   py37hc8dfbb8_1         3.1 MB  conda-forge
#     constantly-15.1.0          |             py_0           9 KB  conda-forge
#     cssselect-1.1.0            |             py_0          18 KB  conda-forge
#     hyperlink-20.0.1           |     pyh9f0ad1d_0          42 KB  conda-forge
#     incremental-17.5.0         |             py_0          14 KB  conda-forge
#     itemadapter-0.1.1          |             py_0          10 KB  conda-forge
#     itemloaders-1.0.3          |             py_0          14 KB  conda-forge
#     jmespath-0.10.0            |     pyh9f0ad1d_0          21 KB  conda-forge
#     parsel-1.6.0               |             py_0          15 KB  conda-forge
#     protego-0.1.16             |             py_0         2.6 MB  conda-forge
#     pyasn1-0.4.8               |             py_0          53 KB  conda-forge
#     pyasn1-modules-0.2.7       |             py_0          60 KB  conda-forge
#     pydispatcher-2.0.5         |             py_1          12 KB  conda-forge
#     pyhamcrest-2.0.2           |             py_0          29 KB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     queuelib-1.5.0             |     pyh9f0ad1d_0          13 KB  conda-forge
#     scrapy-2.3.0               |   py37hc8dfbb8_0         635 KB  conda-forge
#     service_identity-18.1.0    |             py_0          12 KB  conda-forge
#     twisted-20.3.0             |   py37h8055547_0         5.1 MB  conda-forge
#     w3lib-1.22.0               |     pyh9f0ad1d_0          21 KB  conda-forge
#     zope.interface-5.1.2       |   py37h4ab8f01_0         295 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        12.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   automat            conda-forge/noarch::automat-20.2.0-py_0
#   constantly         conda-forge/noarch::constantly-15.1.0-py_0
#   cssselect          conda-forge/noarch::cssselect-1.1.0-py_0
#   hyperlink          conda-forge/noarch::hyperlink-20.0.1-pyh9f0ad1d_0
#   incremental        conda-forge/noarch::incremental-17.5.0-py_0
#   itemadapter        conda-forge/noarch::itemadapter-0.1.1-py_0
#   itemloaders        conda-forge/noarch::itemloaders-1.0.3-py_0
#   jmespath           conda-forge/noarch::jmespath-0.10.0-pyh9f0ad1d_0
#   parsel             conda-forge/noarch::parsel-1.6.0-py_0
#   protego            conda-forge/noarch::protego-0.1.16-py_0
#   pyasn1             conda-forge/noarch::pyasn1-0.4.8-py_0
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.2.7-py_0
#   pydispatcher       conda-forge/noarch::pydispatcher-2.0.5-py_1
#   pyhamcrest         conda-forge/noarch::pyhamcrest-2.0.2-py_0
#   python_abi         conda-forge/win-64::python_abi-3.7-1_cp37m
#   queuelib           conda-forge/noarch::queuelib-1.5.0-pyh9f0ad1d_0
#   scrapy             conda-forge/win-64::scrapy-2.3.0-py37hc8dfbb8_0
#   service_identity   conda-forge/noarch::service_identity-18.1.0-py_0
#   twisted            conda-forge/win-64::twisted-20.3.0-py37h8055547_0
#   w3lib              conda-forge/noarch::w3lib-1.22.0-pyh9f0ad1d_0
#   zope.interface     conda-forge/win-64::zope.interface-5.1.2-py37h4ab8f01_0
#
# The following packages will be UPDATED:
#
#   conda                       pkgs/main::conda-4.8.4-py37_0 --> conda-forge::conda-4.8.5-py37hc8dfbb8_1
#
#
#
# Downloading and Extracting Packages
#
# pyhamcrest-2.0.2     | 29 KB     |            |   0%
# pyhamcrest-2.0.2     | 29 KB     | #####4     |  55%
# pyhamcrest-2.0.2     | 29 KB     | ########## | 100%
# pyhamcrest-2.0.2     | 29 KB     | ########## | 100%
#
# conda-4.8.5          | 3.1 MB    |            |   0%
# conda-4.8.5          | 3.1 MB    | 3          |   3%
# conda-4.8.5          | 3.1 MB    | 9          |  10%
# conda-4.8.5          | 3.1 MB    | ##9        |  30%
# conda-4.8.5          | 3.1 MB    | ###8       |  39%
# conda-4.8.5          | 3.1 MB    | #####      |  51%
# conda-4.8.5          | 3.1 MB    | ######2    |  63%
# conda-4.8.5          | 3.1 MB    | #######2   |  73%
# conda-4.8.5          | 3.1 MB    | ########2  |  82%
# conda-4.8.5          | 3.1 MB    | #########4 |  94%
# conda-4.8.5          | 3.1 MB    | ########## | 100%
#
# scrapy-2.3.0         | 635 KB    |            |   0%
# scrapy-2.3.0         | 635 KB    | ####       |  40%
# scrapy-2.3.0         | 635 KB    | ########## | 100%
# scrapy-2.3.0         | 635 KB    | ########## | 100%
#
# incremental-17.5.0   | 14 KB     |            |   0%
# incremental-17.5.0   | 14 KB     | ########## | 100%
# incremental-17.5.0   | 14 KB     | ########## | 100%
#
# pydispatcher-2.0.5   | 12 KB     |            |   0%
# pydispatcher-2.0.5   | 12 KB     | ########## | 100%
#
# service_identity-18. | 12 KB     |            |   0%
# service_identity-18. | 12 KB     | ########## | 100%
#
# queuelib-1.5.0       | 13 KB     |            |   0%
# queuelib-1.5.0       | 13 KB     | ########## | 100%
#
# hyperlink-20.0.1     | 42 KB     |            |   0%
# hyperlink-20.0.1     | 42 KB     | ########## | 100%
# hyperlink-20.0.1     | 42 KB     | ########## | 100%
#
# zope.interface-5.1.2 | 295 KB    |            |   0%
# zope.interface-5.1.2 | 295 KB    | ########1  |  81%
# zope.interface-5.1.2 | 295 KB    | ########## | 100%
#
# automat-20.2.0       | 30 KB     |            |   0%
# automat-20.2.0       | 30 KB     | ########## | 100%
# automat-20.2.0       | 30 KB     | ########## | 100%
#
# parsel-1.6.0         | 15 KB     |            |   0%
# parsel-1.6.0         | 15 KB     | ########## | 100%
#
# itemadapter-0.1.1    | 10 KB     |            |   0%
# itemadapter-0.1.1    | 10 KB     | ########## | 100%
#
# w3lib-1.22.0         | 21 KB     |            |   0%
# w3lib-1.22.0         | 21 KB     | ########## | 100%
#
# pyasn1-0.4.8         | 53 KB     |            |   0%
# pyasn1-0.4.8         | 53 KB     | ########## | 100%
# pyasn1-0.4.8         | 53 KB     | ########## | 100%
#
# jmespath-0.10.0      | 21 KB     |            |   0%
# jmespath-0.10.0      | 21 KB     | ########## | 100%
#
# cssselect-1.1.0      | 18 KB     |            |   0%
# cssselect-1.1.0      | 18 KB     | ########## | 100%
#
# itemloaders-1.0.3    | 14 KB     |            |   0%
# itemloaders-1.0.3    | 14 KB     | ########## | 100%
#
# twisted-20.3.0       | 5.1 MB    |            |   0%
# twisted-20.3.0       | 5.1 MB    | 3          |   3%
# twisted-20.3.0       | 5.1 MB    | #          |  10%
# twisted-20.3.0       | 5.1 MB    | #6         |  17%
# twisted-20.3.0       | 5.1 MB    | ##5        |  26%
# twisted-20.3.0       | 5.1 MB    | ###5       |  35%
# twisted-20.3.0       | 5.1 MB    | ####4      |  44%
# twisted-20.3.0       | 5.1 MB    | #####3     |  54%
# twisted-20.3.0       | 5.1 MB    | ######     |  61%
# twisted-20.3.0       | 5.1 MB    | ######8    |  69%
# twisted-20.3.0       | 5.1 MB    | #######9   |  79%
# twisted-20.3.0       | 5.1 MB    | ########7  |  87%
# twisted-20.3.0       | 5.1 MB    | #########5 |  95%
# twisted-20.3.0       | 5.1 MB    | ########## | 100%
#
# constantly-15.1.0    | 9 KB      |            |   0%
# constantly-15.1.0    | 9 KB      | ########## | 100%
#
# python_abi-3.7       | 4 KB      |            |   0%
# python_abi-3.7       | 4 KB      | ########## | 100%
#
# protego-0.1.16       | 2.6 MB    |            |   0%
# protego-0.1.16       | 2.6 MB    | 5          |   5%
# protego-0.1.16       | 2.6 MB    | #7         |  18%
# protego-0.1.16       | 2.6 MB    | ###4       |  34%
# protego-0.1.16       | 2.6 MB    | ####5      |  46%
# protego-0.1.16       | 2.6 MB    | ######2    |  63%
# protego-0.1.16       | 2.6 MB    | #######4   |  74%
# protego-0.1.16       | 2.6 MB    | #########3 |  93%
# protego-0.1.16       | 2.6 MB    | ########## | 100%
#
# pyasn1-modules-0.2.7 | 60 KB     |            |   0%
# pyasn1-modules-0.2.7 | 60 KB     | ########## | 100%
# pyasn1-modules-0.2.7 | 60 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.8.5
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
# First, Importing necessary libraries
import scrapy
from scrapy.crawler import CrawlerProcess

# %%
# Secondly, we shoud Define the spider class
# A: for Automatic
class BMW_X3_2018_A(scrapy.Spider):
    
    #name is mandatory, please use the variable "name" for naming your spider.
    #However in this example we won't use it while this project is to show you exactly how to do this.
    name = "bmwx3_2018_A"
    
    #this line is optional. 
    #If you want you can define allowed domains to make sure that your spider only scrape designated domain.
    allowed_domains = ["autoscout24.com"]
    
    #Here you can copy and paste the desired link for scraping
    start_urls = ["https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A\
    &ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&"]
    
    #Write the code for scraping
    def parse(self, response):
        
        items = {}
        
        all_bmwx3_divs = response.css(".cldt-summary-full-item-main")
        
        for bmwx3_divs in all_bmwx3_divs:
            
            model = bmwx3_divs.css(".cldt-summary-makemodel::text").extract_first()
            version = bmwx3_divs.css(".cldt-summary-version::text").extract_first()
            price = bmwx3_divs.css(".cldt-price::text").extract_first()
            km = bmwx3_divs.css(".cldt-summary-vehicle-data > ul > li:nth-child(1)::text").extract_first()
            registration = bmwx3_divs.css(".cldt-summary-vehicle-data > ul > li:nth-child(2)::text").extract_first()
            hp = bmwx3_divs.css(".cldt-summary-vehicle-data > ul > li:nth-child(3)::text").extract_first()
            condition = bmwx3_divs.css(".cldt-summary-vehicle-data > ul > li:nth-child(4)::text").extract_first()
            previous_owner = bmwx3_divs.css(".cldt-summary-vehicle-data > ul > li:nth-child(5)::text").extract_first()
            gear_type = bmwx3_divs.css(".cldt-summary-vehicle-data > ul > li:nth-child(6)::text").extract_first()
            fuel_type = bmwx3_divs.css(".cldt-summary-vehicle-data > ul > li:nth-child(7)::text").extract_first()
            
            items["model"] = model
            items["version"] = version
            items["price"] = price
            items["km"] = km
            items["registration"] = registration
            items["hp"] = hp
            items["condition"] = condition
            items["previous_owner"] = previous_owner
            items["gear_type"] = gear_type
            items["fuel_type"] = fuel_type
    
            #In scraping always use "yield" instead of return
            yield items
        
                            
                
        
process = CrawlerProcess() 

#For crawling prosess use the that you have defined for your Class...
process.crawl(BMW_X3_2018_A) 

# Now run the code and you will get the results below the active window.
process.start()
# Out:
# 2020-10-05 17:00:10 [scrapy.utils.log] INFO: Scrapy 2.3.0 started (bot: scrapybot)
# 2020-10-05 17:00:10 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Windows-10-10.0.18362-SP0
# 2020-10-05 17:00:10 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-10-05 17:00:11 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2020-10-05 17:00:11 [scrapy.extensions.telnet] INFO: Telnet Password: e778965128a0856c
# 2020-10-05 17:00:11 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-10-05 17:00:11 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-10-05 17:00:11 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-10-05 17:00:11 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-10-05 17:00:11 [scrapy.core.engine] INFO: Spider opened
# 2020-10-05 17:00:11 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-10-05 17:00:11 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-10-05 17:00:12 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&> (referer: None)
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20d xLine', 'price': '\n€ 27,117.-\n', 'km': '\n35,656 km\n', 'registration': '\n03/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20d xLine', 'price': '\n€ 27,269.-\n', 'km': '\n35,178 km\n', 'registration': '\n03/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20d xLine', 'price': '\n€ 27,330.-\n', 'km': '\n35,364 km\n', 'registration': '\n03/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20d xLine', 'price': '\n€ 27,395.-\n', 'km': '\n35,942 km\n', 'registration': '\n03/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20d xLine', 'price': '\n€ 27,453.-\n', 'km': '\n35,926 km\n', 'registration': '\n03/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20d xLine', 'price': '\n€ 27,481.-\n', 'km': '\n35,385 km\n', 'registration': '\n03/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20d xLine', 'price': '\n€ 27,631.-\n', 'km': '\n35,677 km\n', 'registration': '\n03/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20d xLine', 'price': '\n€ 27,681.-\n', 'km': '\n35,888 km\n', 'registration': '\n04/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20d xLine', 'price': '\n€ 27,756.-\n', 'km': '\n35,440 km\n', 'registration': '\n03/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20d xLine', 'price': '\n€ 27,935.-\n', 'km': '\n35,557 km\n', 'registration': '\n03/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20d xLine', 'price': '\n€ 27,946.-\n', 'km': '\n35,116 km\n', 'registration': '\n03/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20d xLine', 'price': '\n€ 27,990.-\n', 'km': '\n35,736 km\n', 'registration': '\n03/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20d xLine', 'price': '\n€ 27,994.-\n', 'km': '\n35,212 km\n', 'registration': '\n03/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive 20dA', 'price': '\n€ 28,700.-\n', 'km': '\n50,000 km\n', 'registration': '\n05/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive 20dA', 'price': '\n€ 28,700.-\n', 'km': '\n50,000 km\n', 'registration': '\n05/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20i Aut. Advantage', 'price': '\n€ 28,700.-\n', 'km': '\n27,000 km\n', 'registration': '\n06/2018\n', 'hp': '\n135 kW (184 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nGasoline\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive20d xLine', 'price': '\n€ 29,000.-\n', 'km': '\n35,000 km\n', 'registration': '\n02/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'sDrive 18dA Business', 'price': '\n€ 29,500.-\n', 'km': '\n39,500 km\n', 'registration': '\n06/2018\n', 'hp': '\n110 kW (150 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive 20dA', 'price': '\n€ 30,750.-\n', 'km': '\n60,000 km\n', 'registration': '\n06/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n-/- (Previous Owners)\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.autoscout24.com/lst/bmw/x3?sort=price&desc=0&gear=A%20%20%20%20&ustate=N%2CU&size=20&page=1&fregto=2018&fregfrom=2018&atype=C&>
# {'model': 'BMW X3', 'version': 'xDrive 20d KLIMA PDC AHK SHZ NAVI LED EU6', 'price': '\n€ 30,890.-\n', 'km': '\n85,609 km\n', 'registration': '\n11/2018\n', 'hp': '\n140 kW (190 hp)\n', 'condition': '\nUsed\n', 'previous_owner': '\n1 previous owner\n', 'gear_type': '\nAutomatic\n', 'fuel_type': '\nDiesel\n'}
# 2020-10-05 17:00:12 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-10-05 17:00:12 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 329,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 102353,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 1.026732,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 10, 5, 14, 0, 12, 464329),
#  'item_scraped_count': 20,
#  'log_count/DEBUG': 21,
#  'log_count/INFO': 10,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 10, 5, 14, 0, 11, 437597)}
# 2020-10-05 17:00:12 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# As you can see crawling and scraping completed succesfully.
# You can save your results to an output file if you want using the code below.
# Just update the code with the code given below.

# %%
#save to a Json file
process = CrawlerProcess({'FEED_URI': 'output.json'})
# Out:
# 2020-10-05 17:00:40 [scrapy.utils.log] INFO: Scrapy 2.3.0 started (bot: scrapybot)
# 2020-10-05 17:00:40 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Windows-10-10.0.18362-SP0
# 2020-10-05 17:00:40 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor

# %%
#saving to a csv file
process = CrawlerProcess({'FEED_URI': 'output.csv'})

#I do not recommend saving to csv since csv uses comma to separate colums.
#And this could make your scraped date split into unwanted columns.

#Thank you!
# Out:
# 2020-10-05 17:03:00 [scrapy.utils.log] INFO: Scrapy 2.3.0 started (bot: scrapybot)
# 2020-10-05 17:03:00 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Windows-10-10.0.18362-SP0
# 2020-10-05 17:03:00 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
